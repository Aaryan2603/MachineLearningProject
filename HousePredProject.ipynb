# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
data="C:\\Users\\vatsa\\Python\\Mac\\train.csv"
datatrain="C:\\Users\\vatsa\\Python\\Mac\\test.csv"
X_data=pd.read_csv(data)
X_test=pd.read_csv(datatrain)
X_data.dropna(axis=0, subset=['SalePrice'], inplace=True)
y = X_data.SalePrice

# %%
#y = X.SalePrice
features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X=X_data[features].copy()
X_test=X_test[features].copy()

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, train_size=0.8, test_size=0.2,random_state=0)

# %%
X_train.head()
missing_val_count_by_column = (X.isnull().sum())
print(missing_val_count_by_column[missing_val_count_by_column > 0])
# Out:
# Series([], dtype: int64)

# %%
model= RandomForestRegressor(n_estimators=100, random_state=0)
def score_model(model, X_t=X_train, X_v=X_valid, y_t=y_train, y_v=y_valid):
    model.fit(X_t, y_t)
    preds = model.predict(X_v)
    return mean_absolute_error(y_v, preds)
score_model(model)
# Out:
# 23740.979228636657

# %%
model.predict(X_val)
# Out:
# array([277080.        , 155483.5       , 121558.5       , 193209.        ,
#         90431.41666667,  93324.83      , 246849.9       , 125765.        ,
#        627699.33      , 169720.08      , 207514.09      , 155659.5       ,
#        235239.3       , 124127.66      , 136160.68      , 131841.08      ,
#        228922.9       , 133609.        , 150954.87      , 130098.78      ,
#        136140.32      , 147392.04285714, 110737.61      , 183943.02      ,
#        154181.08      , 179653.44      , 174506.25      ,  85204.11      ,
#        322793.88      , 115426.76      , 141807.5       , 190125.5       ,
#        124945.82      , 282878.79      , 310586.24      , 175306.95      ,
#        220060.33      , 120108.33      , 223485.5       , 306767.33      ,
#        223833.        , 142519.5       , 187500.5       , 306340.19      ,
#        320342.49      , 137621.        , 104569.41      , 126270.        ,
# ...
